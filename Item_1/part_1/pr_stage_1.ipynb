# %%
3 + 2
# Out:
# 5

# %%
a = 1
print(a)
# Out:
# 1

# %% [markdown]
# # Пример md (текст который является по сути смысловым комментарием)
#
# #### Заголовок 4-го уровня
#
# **Выделенный блок**
#
# - item_1
# - item_2
# - item_3

# %%
1.3 + 7
# Out:
# 8.3

# %%
8.6 - 5.9
# Out:
# 2.6999999999999993

# %%
2 * 4
# Out:
# 8

# %%
2 ** 4
# Out:
# 16

# %%
8 // 3.4
# Out:
# 2.0

# %%
print('hello')
# Out:
# hello

# %%
19 + 3.0
# Out:
# 22.0

# %%
print('19 + 3.0 =', 19 + 3.0, 'где type: ', type(19 + 3.0))
# Out:
# 19 + 3.0 = 22.0 где type:  <class 'float'>

# %%
print('19 + 3.0 =', 19 + 3.0, 'где type: ', type(19 + 3.0))
# Out:
# 19 + 3.0 = 22.0 где type:  <class 'float'>

# %%
print(a, type(a))
# Out:
# 1 <class 'int'>

# %%
operand1 = -13
operand2 = 5

res = operand1 + operand2

print(res)
# Out:
# -8

# %%
print(operand1)
# Out:
# -13

# %%
operand2
# Out:
# 5

# %%
import math
res1 = operand1 - math.floor(operand1 / operand2) * operand2
res2 = operand1 % operand2
print(res1, res2)
# Out:
# 2 2

# %%
print(operand3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(operand3)
#
# NameError: name 'operand3' is not defined

# %%
operand3 = 'всем привет'
print(operand3)
# Out:
# всем привет

# %%
Example
example

# %%
a = 10
b = 20
print(a == b) # =: присвоение; ==: равенство
# Out:
# False

# %%
type(a == b)
# Out:
# bool

# %%
print(a != b) # != не равно
# Out:
# True

# %%
c = 10

# %%
print(a == c)
# Out:
# True

# %% [markdown]
# ```
# 19 + 3.0
# 36 / 6
# 4 + 2 * 5
# 5 % 2
# 56 % 10
# 8 % 41
# 89 // 15
# 17 - 45 // 8
# 2 ** 2
# 2 ** 2 ** 2
# 3 ** (3 ** 2)
# (3 ** 3) ** 2
# 16 ** 0.5
# -13 % -3
# -13 % -4
# -13 % 3
# -13 % 4
# ```

# %%
print('19 + 3.0 =', 19 + 3.0, 'где type: ', type(19 + 3.0))
# Out:
# 19 + 3.0 = 22.0 где type:  <class 'float'>

# %% [markdown]
# # var Var

# %% [markdown]
# ### Вопрос 1
# Как называется текст программы на любом языке программирования?
#
# Варианты ответов:
#
# 1.   Программным кодом ✅
# 2.   Переменной
# 3.   Статической типизацией
# 4.   Динамической типизацией
#
# Правильный ответ можно обозначить эмодзи: ✅
#
# ### Вопрос 2
# В Python используется:
#
# Варианты ответов:
#
# 1.   Статическая типизация
# 2.   Динамическая типизация ✅
# 3.   Любая типизация
# 4.   Никакая типизация
#
# Правильный ответ можно обозначить эмодзи: ✅
#
#
# ### Вопрос 3
# Выберите правильное название переменной в Python:
#
# Варианты ответов:
#
# 1.   1_name
# 2.   &name
# 3.   ~name
# 4.   name_1 ✅
#
# Правильный ответ можно обозначить эмодзи: ✅
#
#
# ### Вопрос 4
# Переменная с именем "Name" и переменная "name" это одна и та же переменная в Python?
#
# Варианты ответов:
#
# 1.   Да, потому что регистр букв в Python не имеет значения
# 2.   Нет, потому что одна переменная начинается с маленькой буквы, а другая с заглавной. Python регистрозависимый ✅
#
# Правильный ответ можно обозначить эмодзи:
#
# ### Вопрос 5
# Что произойдет, если обратиться к переменой `good` до того момента, когда она будет объявлена?
#
# Варианты ответов:
#
# 1.   исключение `NameError: name 'good' is not defined` ✅
# 2.   выведется значение переменной `good`, которую мы объявили позже
#
# Правильный ответ можно обозначить эмодзи:
#
# ### Вопрос 6
# Что произойдет, если попытаться выполнить следующую команду?
#
# `False = 666`
#
# SyntaxError

# %%
False = 666
# Out:
#   Cell In[25], line 1
#     False = 666
#     ^
# SyntaxError: cannot assign to False

# %%
examlpe_demo = 666

# %%
a = input()
# Out:
#  200

# %%
a = input("Введите информамцию для сохранения:")
# Out:
# Введите информамцию для сохранения: 12345

# %%
print(a)
# Out:
# 12345

# %%
print("Привет, меня зовут Николай")
# Out:
# Привет, меня зовут Николай

# %%
print("Привет,", "меня зовут", "Николай")
# Out:
# Привет, меня зовут Николай

# %%
print("Привет,", "меня зовут", "Николай", sep="____")
# Out:
# Привет,____меня зовут____Николай

# %%
print("Привет,", "меня зовут", "Николай", sep="____", end='Это конец строки')
# Out:
# Привет,____меня зовут____НиколайЭто конец строки

# %%
print('Привет, меня зовут Николай ', a)
# Out:
# Привет, меня зовут Николай  12345

# %%
print(f"Привет, меня зовут Николай {a}")
# Out:
# Привет, меня зовут Николай 12345

# %% [markdown]
# Вашей программе поступает на вход натуральное число. Ваша задача вывести в отдельных строках:
#
# * число, увеличенное в 2 раза
# * число, уменьшенное в 2 раза
#
# **Ввод**:\
# 8
#
# **Вывод**:\
# 16\
# 4.0
#
# **Ввод**:\
# 5
#
# **Вывод**:\
# 10\
# 2.5

# %%
a = int(input())
print(a*2)
print(a/2)
# Out:
#  8
# 16
# 4.0

# %% [markdown]
# На вход поступает одно число - длина квадрата. Нужно вывести его площадь.
#
# **Ввод**:\
# 7
#
# **Вывод**:\
# 49.0
#
# **Ввод**:\
# 1.5
#
# **Вывод**:\
# 2.25

# %%
a = float(input())
print(a**2)
# Out:
#  7
# 49.0

# %% [markdown]
# Задача 8. Сумма двух чисел
#
# Напишите программу, которая принимает на вход два целых числа в отдельных строках и выводит на экран их сумму.

# %%
a = int(input())
b = int(input())
print(a+b)
# Out:
#  10
#  20
# 30

# %% [markdown]
# Вычислите площадь и периметр прямоугольника по введенным сторонам:

# %%
a = float(input())
b = float(input())
print(a*b, 2*(a+b))
# Out:
#  7
#  2
# 14.0 18.0

# %% [markdown]
# Даны значения двух моментов времени, принадлежащих одним и тем же суткам: часы, минуты и секунды для каждого из моментов времени. Известно, что второй момент времени наступил не раньше первого. Определите, сколько секунд прошло между двумя моментами времени.
#
# **Входные данные**\
# Программа на вход получает три целых числа: часы, минуты, секунды, задающие первый момент времени и три целых числа, задающих второй момент времени.
#
# **Выходные данные**\
# Выведите число секунд между этими моментами времени.
#
# **Ввод**:\
# 1\
# 1\
# 1\
# 2\
# 2\
# 2
#
# **Вывод**:\
# 3661
#
# **Ввод**:\
# 1\
# 2\
# 30\
# 1\
# 3\
# 20
#
# **Вывод**:\
# 50

# %%
h1 = int(input())
m1 = int(input())
s1 = int(input())
h2 = int(input())
m2 = int(input())
s2 = int(input())
ts1 = h1*3600 + m1*60 + s1
ts2 = h2*3600 + m2*60 + s2
print(abs(ts2-ts1))
# Out:
#  1
#  1
#  1
#  2
#  2
#  2
# 3661

# %%
# == - сравнение на равенство
# != - сравнение на неравенство
# > - больше
# < - меньше
# >= больше или равно
# <= меньше или равно

# %%
a = int(input())
print(a >= 0)
# Out:
#  -30
# False

# %% [markdown]
# Программа должна вывести True, если введенное значение является четным числом, в противном случае - False.

# %%
print(int(input()) % 2 == 0)
# Out:
#  6
# True

# %%
a = 10
if a == 10:
    print("Число равно десять")
# Out:
# Число равно десять

# %%
a = 11
if a == 10:
    print("Число равно десять")
else:
    print("Число не равно десять")
# Out:
# Число не равно десять

# %%
a = 20
if a == 10:
    print("Число равно десять")
elif a == 11:
    print("Число равно одиннадцать")
elif a == 12:
    print("Число равно 12")
elif a == 13:
    print("Число равно 13")
elif a == 14:
    print("Число равно 14")
else:
    print("Число не равно десять или одиннадцать или 12 или 13 или 14")
# Out:
# Число не равно десять или одиннадцать или 12 или 13 или 14
