# %% [markdown]
# # Сборник задач по основам Python для обработки данных
#
# Версия для слушателей.
#
# ## Содержание
#
# 1. Переменные, типы данных, расчёты и строки.
# 2. Управление потоком: `if`, `for`, `while`.
# 3. NumPy: базовые операции с массивами.
# 4. pandas: `Series`, `DataFrame` и базовый анализ.
# 5. Jupyter Notebook: организация кода и визуальный вывод.
#
# ## Правила работы
#
# - Выполняйте notebook сверху вниз.
# - Под каждой задачей оставлено поле для программного кода.
# - Не удаляйте исходные данные и формулировки заданий.
# - После завершения выполните **Run all**.
# - Сохраните результат в формате `.ipynb`.
#
# Задания идут от простых к более сложным. Итоговые мини-кейсы размещены в конце каждого раздела.

# %% [markdown]
# # Раздел 1. Переменные, типы данных, расчёты и строки

# %% [markdown]
# ## Задача 1. Карточка показателей
#
#
# Создайте переменные:
#
# - `city = "Тула"`;
# - `orders_count = 24`;
# - `revenue = 138500.75`;
# - `plan_completed = True`.
#
# Выведите каждую переменную и её тип.

# %%
# Напишите решение ниже

# %% [markdown]
# ## Задача 2. Выручка
#
#
# Цена товара — 2 450 рублей, продано 8 единиц.
#
# Рассчитайте выручку и выведите результат.

# %%
unit_price = 2450
quantity = 8

# Напишите решение ниже

# %% [markdown]
# ## Задача 3. Скидка
#
#
# Сумма заказа до скидки — 18 500 рублей. Скидка — 7%.
#
# Рассчитайте:
#
# 1. размер скидки;
# 2. итоговую сумму заказа.

# %%
amount_before_discount = 18500
discount_rate = 0.07

# Напишите решение ниже

# %% [markdown]
# ## Задача 4. Средний чек
#
#
# Общая выручка — 96 000 рублей, количество заказов — 17.
#
# Рассчитайте средний чек и выведите его с двумя знаками после запятой.

# %%
total_revenue = 96000
orders_count = 17

# Напишите решение ниже

# %% [markdown]
# ## Задача 5. Маржа
#
#
# Цена продажи одной единицы — 5 200 рублей, себестоимость — 3 600 рублей, продано 11 единиц.
#
# Рассчитайте:
#
# - общую выручку;
# - общую себестоимость;
# - маржу.

# %%
unit_price = 5200
unit_cost = 3600
quantity = 11

# Напишите решение ниже

# %% [markdown]
# ## Задача 6. Доля возвратов
#
#
# За месяц было 240 заказов, из них 18 вернули.
#
# Рассчитайте долю возвратов в процентах и выведите её с одним знаком после запятой.

# %%
orders_count = 240
returns_count = 18

# Напишите решение ниже

# %% [markdown]
# ## Задача 7. Преобразование типов
#
#
# Даны значения, загруженные как текст:
#
# ```python
# quantity_text = "6"
# price_text = "1499.50"
# ```
#
# Преобразуйте их в числа, рассчитайте выручку и выведите тип результата.

# %%
quantity_text = "6"
price_text = "1499.50"

# Напишите решение ниже

# %% [markdown]
# ## Задача 8. Остаток упаковок
#
#
# На складе 53 товара. В одну коробку помещается 8 товаров.
#
# Найдите:
#
# - количество полностью заполненных коробок;
# - количество товаров, которые останутся без полной коробки.
#
# Используйте операции `//` и `%`.

# %%
items_count = 53
box_capacity = 8

# Напишите решение ниже

# %% [markdown]
# ## Задача 9. Очистка названия города
#
#
# Дано значение:
#
# ```python
# raw_city = "  нИЖний ноВгород  "
# ```
#
# Удалите пробелы по краям и приведите название к виду `Нижний Новгород`.

# %%
raw_city = "  нИЖний ноВгород  "

# Напишите решение ниже

# %% [markdown]
# ## Задача 10. Замена текста
#
#
# Дано название категории:
#
# ```python
# category = "мобильные телефоны"
# ```
#
# Замените слово `телефоны` на `устройства`.

# %%
category = "мобильные телефоны"

# Напишите решение ниже

# %% [markdown]
# ## Задача 11. Отчётная строка
#
#
# Создайте одну f-строку по шаблону:
#
# ```text
# Пермь: 31 заказ, выручка 174250.50 руб.
# ```
#
# Исходные данные:
#
# ```python
# city = "Пермь"
# orders_count = 31
# revenue = 174250.5
# ```

# %%
city = "Пермь"
orders_count = 31
revenue = 174250.5

# Напишите решение ниже

# %% [markdown]
# ## Задача 12. Мини-кейс: показатели продаж
#
#
# За неделю магазин получил 42 заказа. Общая выручка — 315 600 рублей. Себестоимость проданных товаров — 211 200 рублей. Возвращено 3 заказа.
#
# Рассчитайте:
#
# 1. средний чек;
# 2. маржу;
# 3. долю возвратов в процентах;
# 4. сформируйте итоговую строку с результатами.

# %%
orders_count = 42
total_revenue = 315600
total_cost = 211200
returns_count = 3

# Напишите решение ниже

# %% [markdown]
# ## Чек-лист
#
# - Все 12 задач выполнены.
# - Код запускается сверху вниз.
# - Значения выводятся в понятном формате.
# - Для денежных показателей использовано округление там, где оно требуется.
# - Файл сохранён в формате `.ipynb`.

# %% [markdown]
# ---

# %% [markdown]
# # Раздел 2. Управление потоком: условия и циклы

# %% [markdown]
# ## Задача 1. Выполнение плана
#
#
# Дано:
#
# ```python
# revenue = 108000
# plan = 100000
# ```
#
# Выведите `План выполнен`, если выручка не меньше плана, иначе — `План не выполнен`.

# %%
revenue = 108000
plan = 100000

# Напишите решение ниже

# %% [markdown]
# ## Задача 2. Категория заказа
#
#
# Правила:
#
# - меньше 3 000 — `Небольшой`;
# - от 3 000 до 10 000 включительно — `Средний`;
# - больше 10 000 — `Крупный`.
#
# Определите категорию для `order_amount = 8450`.

# %%
order_amount = 8450

# Напишите решение ниже

# %% [markdown]
# ## Задача 3. Два условия одновременно
#
#
# Результат считается хорошим, если:
#
# - выручка не меньше 120 000 рублей;
# - доля возвратов не больше 5%.
#
# Используйте:
#
# ```python
# revenue = 126000
# returns_rate = 0.04
# ```

# %%
revenue = 126000
returns_rate = 0.04

# Напишите решение ниже

# %% [markdown]
# ## Задача 4. Условие `or`
#
#
# Заказ требует ручной проверки, если сумма больше 100 000 рублей **или** количество товаров больше 20.
#
# Используйте:
#
# ```python
# order_amount = 85000
# quantity = 24
# ```

# %%
order_amount = 85000
quantity = 24

# Напишите решение ниже

# %% [markdown]
# ## Задача 5. Вывод элементов списка
#
#
# Дан список городов:
#
# ```python
# cities = ["Москва", "Казань", "Самара", "Пермь"]
# ```
#
# Выведите каждый город на отдельной строке с помощью `for`.

# %%
cities = ["Москва", "Казань", "Самара", "Пермь"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 6. Общая выручка в цикле
#
#
# Дан список дневной выручки:
#
# ```python
# daily_revenue = [12500, 9800, 14300, 11700, 15600]
# ```
#
# Посчитайте общую выручку с помощью цикла `for`, не используя `sum()`.

# %%
daily_revenue = [12500, 9800, 14300, 11700, 15600]

# Напишите решение ниже

# %% [markdown]
# ## Задача 7. Подсчёт крупных заказов
#
#
# Дан список:
#
# ```python
# order_amounts = [2500, 12000, 7800, 15600, 4300, 10200]
# ```
#
# Посчитайте количество заказов больше 10 000 рублей.

# %%
order_amounts = [2500, 12000, 7800, 15600, 4300, 10200]

# Напишите решение ниже

# %% [markdown]
# ## Задача 8. Сбор подходящих значений
#
#
# Из списка заказов соберите новый список, содержащий только суммы не меньше 8 000 рублей.
#
# ```python
# order_amounts = [2500, 12000, 7800, 15600, 4300, 10200]
# ```

# %%
order_amounts = [2500, 12000, 7800, 15600, 4300, 10200]

# Напишите решение ниже

# %% [markdown]
# ## Задача 9. Нумерация строк
#
#
# Выведите список товаров с порядковыми номерами, начиная с 1:
#
# ```python
# products = ["Ноутбук", "Мышь", "Клавиатура"]
# ```
#
# Используйте `enumerate()`.

# %%
products = ["Ноутбук", "Мышь", "Клавиатура"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 10. Обработка списка словарей
#
#
# Дан список заказов:
#
# ```python
# orders = [
#     {"order_id": "ORD-001", "city": "Москва", "amount": 12500},
#     {"order_id": "ORD-002", "city": "Казань", "amount": 4800},
#     {"order_id": "ORD-003", "city": "Москва", "amount": 9200}
# ]
# ```
#
# Выведите идентификаторы только московских заказов.

# %%
orders = [
    {"order_id": "ORD-001", "city": "Москва", "amount": 12500},
    {"order_id": "ORD-002", "city": "Казань", "amount": 4800},
    {"order_id": "ORD-003", "city": "Москва", "amount": 9200}
]

# Напишите решение ниже

# %% [markdown]
# ## Задача 11. Цикл `while`
#
#
# С помощью `while` выведите числа от 1 до 5.
#
# Сохраните выведенные числа в список `result`.

# %%
counter = 1
result = []

# Напишите решение ниже

# %% [markdown]
# ## Задача 12. Накопление до плана
#
#
# Дана дневная выручка:
#
# ```python
# daily_revenue = [12000, 15000, 18000, 9000]
# ```
#
# С помощью `while` определите, сколько первых дней понадобилось, чтобы накопленная выручка достигла 40 000 рублей.

# %%
daily_revenue = [12000, 15000, 18000, 9000]
target = 40000

# Напишите решение ниже

# %% [markdown]
# ## Задача 13. Мини-кейс: отчёт по заказам
#
#
# Дан список:
#
# ```python
# orders = [
#     {"order_id": "ORD-001", "amount": 3500, "is_paid": True},
#     {"order_id": "ORD-002", "amount": 9200, "is_paid": True},
#     {"order_id": "ORD-003", "amount": 12800, "is_paid": False},
#     {"order_id": "ORD-004", "amount": 5700, "is_paid": True},
#     {"order_id": "ORD-005", "amount": 14600, "is_paid": True}
# ]
# ```
#
# Найдите:
#
# 1. общую сумму заказов;
# 2. количество оплаченных заказов;
# 3. количество заказов больше 10 000 рублей;
# 4. средний чек;
# 5. статус выполнения плана 40 000 рублей.

# %%
orders = [
    {"order_id": "ORD-001", "amount": 3500, "is_paid": True},
    {"order_id": "ORD-002", "amount": 9200, "is_paid": True},
    {"order_id": "ORD-003", "amount": 12800, "is_paid": False},
    {"order_id": "ORD-004", "amount": 5700, "is_paid": True},
    {"order_id": "ORD-005", "amount": 14600, "is_paid": True}
]
plan = 40000

# Напишите решение ниже

# %% [markdown]
# ## Чек-лист
#
# - Использованы правильные операторы сравнения.
# - Соблюдены отступы в `if`, `for` и `while`.
# - Цикл `while` изменяет переменную условия.
# - Итоговый мини-кейс запускается без ошибок.

# %% [markdown]
# ---

# %% [markdown]
# # Раздел 3. NumPy: базовые операции с массивами

# %% [markdown]
# ## Задача 1. Создание массива
#
#
# Создайте массив NumPy:
#
# ```python
# [12000, 15000, 9000, 18000, 16000]
# ```
#
# Выведите сам массив и его тип.

# %%
import numpy as np

# Напишите решение ниже

# %% [markdown]
# ## Задача 2. Свойства массива
#
#
# Для массива из задачи 1 выведите:
#
# - `shape`;
# - `ndim`;
# - `dtype`;
# - `size`.

# %%
import numpy as np
revenue = np.array([12000, 15000, 9000, 18000, 16000])

# Напишите решение ниже

# %% [markdown]
# ## Задача 3. Индексация и срезы
#
#
# Для массива:
#
# ```python
# values = np.array([100, 200, 300, 400, 500])
# ```
#
# Выведите:
#
# 1. первый элемент;
# 2. последний элемент;
# 3. первые три элемента;
# 4. элементы со второго по четвёртый.

# %%
import numpy as np
values = np.array([100, 200, 300, 400, 500])

# Напишите решение ниже

# %% [markdown]
# ## Задача 4. Увеличение цен
#
#
# Дан массив:
#
# ```python
# prices = np.array([1000, 2500, 4000, 5200])
# ```
#
# Увеличьте все цены на 8% одной операцией.

# %%
import numpy as np
prices = np.array([1000, 2500, 4000, 5200])

# Напишите решение ниже

# %% [markdown]
# ## Задача 5. Выручка по товарам
#
#
# Даны цены и количества:
#
# ```python
# prices = np.array([1200, 2500, 4100])
# quantities = np.array([5, 3, 2])
# ```
#
# Рассчитайте выручку по каждому товару и общую выручку.

# %%
import numpy as np
prices = np.array([1200, 2500, 4100])
quantities = np.array([5, 3, 2])

# Напишите решение ниже

# %% [markdown]
# ## Задача 6. Агрегаты
#
#
# Для массива:
#
# ```python
# revenue = np.array([12000, 15000, 9000, 18000, 16000])
# ```
#
# Найдите сумму, среднее, медиану, минимум и максимум.

# %%
import numpy as np
revenue = np.array([12000, 15000, 9000, 18000, 16000])

# Напишите решение ниже

# %% [markdown]
# ## Задача 7. Логическая маска
#
#
# Выберите значения больше 14 000 из массива:
#
# ```python
# revenue = np.array([12000, 15000, 9000, 18000, 16000])
# ```

# %%
import numpy as np
revenue = np.array([12000, 15000, 9000, 18000, 16000])

# Напишите решение ниже

# %% [markdown]
# ## Задача 8. Подсчёт по условию
#
#
# Посчитайте количество заказов больше 10 000 рублей:
#
# ```python
# order_amounts = np.array([2500, 12000, 7800, 15600, 4300, 10200])
# ```

# %%
import numpy as np
order_amounts = np.array([2500, 12000, 7800, 15600, 4300, 10200])

# Напишите решение ниже

# %% [markdown]
# ## Задача 9. Несколько условий
#
#
# Выберите значения от 5 000 до 12 000 включительно:
#
# ```python
# order_amounts = np.array([2500, 12000, 7800, 15600, 4300, 10200])
# ```

# %%
import numpy as np
order_amounts = np.array([2500, 12000, 7800, 15600, 4300, 10200])

# Напишите решение ниже

# %% [markdown]
# ## Задача 10. `np.where()`
#
#
# Создайте массив категорий:
#
# - `Крупный`, если сумма больше 10 000;
# - `Обычный` — в остальных случаях.
#
# Используйте:
#
# ```python
# order_amounts = np.array([2500, 12000, 7800, 15600])
# ```

# %%
import numpy as np
order_amounts = np.array([2500, 12000, 7800, 15600])

# Напишите решение ниже

# %% [markdown]
# ## Задача 11. Двумерный массив
#
#
# Создайте двумерный массив:
#
# ```python
# [
#     [10, 20, 30],
#     [40, 50, 60]
# ]
# ```
#
# Выведите:
#
# 1. форму массива;
# 2. первую строку;
# 3. второй столбец;
# 4. сумму всех элементов.

# %%
import numpy as np

# Напишите решение ниже

# %% [markdown]
# ## Задача 12. Мини-кейс NumPy
#
#
# Даны суммы заказов:
#
# ```python
# orders = np.array([3500, 9200, 12800, 5700, 14600, 4100])
# ```
#
# Найдите:
#
# 1. общую сумму;
# 2. среднее;
# 3. медиану;
# 4. количество заказов больше среднего;
# 5. массив категорий `Выше среднего` / `Не выше среднего`.

# %%
import numpy as np
orders = np.array([3500, 9200, 12800, 5700, 14600, 4100])

# Напишите решение ниже

# %% [markdown]
# ## Чек-лист
#
# - NumPy импортирован как `np`.
# - Операции выполняются над массивами без ручных циклов.
# - Для нескольких условий использованы круглые скобки и оператор `&`.
# - Все 12 задач выполнены.

# %% [markdown]
# ---

# %% [markdown]
# # Раздел 4. pandas: Series, DataFrame и базовый анализ

# %% [markdown]
# ## Задача 1. Создание `Series`
#
#
# Создайте `Series` из городов:
#
# ```python
# ["Москва", "Казань", "Самара"]
# ```
#
# Дайте объекту имя `city`.

# %%
import pandas as pd

# Напишите решение ниже

# %% [markdown]
# ## Задача 2. `Series` с индексом
#
#
# Создайте `Series` выручки по городам:
#
# - Москва — 125 000;
# - Казань — 87 000;
# - Самара — 93 000.
#
# Используйте названия городов как индекс. Затем получите значение Москвы через `.loc`.

# %%
import pandas as pd

# Напишите решение ниже

# %% [markdown]
# ## Задача 3. Создание `DataFrame`
#
#
# Создайте таблицу `products` со столбцами:
#
# - `product`: Ноутбук, Мышь, Клавиатура;
# - `price`: 70000, 1500, 3500;
# - `in_stock`: True, True, False.

# %%
import pandas as pd

# Напишите решение ниже

# %% [markdown]
# ## Задача 4. Просмотр структуры таблицы
#
#
# Для готовой таблицы `sales` выведите:
#
# - первые три строки;
# - размер таблицы;
# - список столбцов;
# - типы данных.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 5. Выбор столбцов
#
#
# Выберите из `sales`:
#
# 1. один столбец `city`;
# 2. три столбца: `order_id`, `product`, `quantity`.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 6. `iloc` и `loc`
#
#
# Выведите:
#
# 1. первую строку таблицы через `iloc`;
# 2. значения `order_id`, `city`, `product` первой строки через `loc`.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 7. Простая фильтрация
#
#
# Выберите все продажи из Москвы.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 8. Фильтрация по двум условиям
#
#
# Выберите строки, где:
#
# - город — Казань;
# - количество не меньше 4.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 9. Расчётный столбец
#
#
# Создайте столбец `revenue`:
#
# ```text
# revenue = quantity × unit_price
# ```

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 10. Категория заказа
#
#
# После расчёта `revenue` создайте столбец `order_category`:
#
# - `Крупный`, если выручка строки больше 50 000;
# - `Обычный` — иначе.
#
# Используйте `np.where()`.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

sales["revenue"] = sales["quantity"] * sales["unit_price"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 11. Сортировка
#
#
# Рассчитайте `revenue` и отсортируйте таблицу от большей выручки к меньшей.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

sales["revenue"] = sales["quantity"] * sales["unit_price"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 12. Уникальные значения и частоты
#
#
# Выведите:
#
# 1. уникальные города;
# 2. количество уникальных городов;
# 3. частоту каждого города.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Задача 13. Группировка по городу
#
#
# Рассчитайте `revenue`, затем найдите суммарную выручку по каждому городу.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

sales["revenue"] = sales["quantity"] * sales["unit_price"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 14. Несколько агрегатов
#
#
# Для каждого города рассчитайте:
#
# - количество строк;
# - суммарное количество единиц;
# - суммарную выручку;
# - среднюю выручку строки.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

sales["revenue"] = sales["quantity"] * sales["unit_price"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 15. Простой график
#
#
# Рассчитайте суммарную выручку по городам и постройте столбчатую диаграмму.
#
# Добавьте:
#
# - заголовок;
# - подписи осей;
# - `tight_layout()`.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

import matplotlib.pyplot as plt

sales["revenue"] = sales["quantity"] * sales["unit_price"]

# Напишите решение ниже

# %% [markdown]
# ## Задача 16. Мини-кейс pandas
#
#
# На основе `sales`:
#
# 1. создайте `revenue`;
# 2. найдите общую выручку;
# 3. определите город-лидер;
# 4. определите товар-лидер по количеству;
# 5. выберите строки с выручкой больше 10 000;
# 6. сформулируйте короткий вывод через `print()`.

# %%
import pandas as pd
import numpy as np

sales = pd.DataFrame({
    "order_id": ["ORD-001", "ORD-002", "ORD-003", "ORD-004", "ORD-005", "ORD-006"],
    "city": ["Москва", "Казань", "Москва", "Самара", "Казань", "Самара"],
    "product": ["Ноутбук", "Мышь", "Клавиатура", "Ноутбук", "Клавиатура", "Мышь"],
    "quantity": [2, 5, 3, 1, 4, 6],
    "unit_price": [70000, 1500, 3500, 72000, 3400, 1450]
})

# Напишите решение ниже

# %% [markdown]
# ## Чек-лист
#
# - pandas импортирован как `pd`.
# - Таблица исследована до выполнения расчётов.
# - При фильтрации по нескольким условиям использованы круглые скобки.
# - Группировки возвращают понятные итоговые таблицы.
# - График содержит заголовок и подписи осей.

# %% [markdown]
# ---

# %% [markdown]
# # Раздел 5. Jupyter Notebook: организация кода и визуальный вывод

# %% [markdown]
# ## Задача 1. Заголовок и цель работы
#
# В следующей Markdown-ячейке напишите:
#
# 1. название мини-анализа;
# 2. цель;
# 3. ожидаемый результат.
#
# Используйте заголовки Markdown и маркированный список.

# %% [markdown]
# <!-- Заполните эту Markdown-ячейку -->

# %% [markdown]
# ## Задача 2. Импорт библиотек
#
# В одной кодовой ячейке импортируйте:
#
# - pandas как `pd`;
# - matplotlib.pyplot как `plt`.
#
# Выведите версии Python и pandas.

# %%
# Напишите решение ниже

# %% [markdown]
# ## Задача 3. Создание учебной таблицы
#
# Создайте `DataFrame` `sales`:
#
# | city | category | revenue |
# |---|---|---:|
# | Москва | Электроника | 125000 |
# | Казань | Электроника | 87000 |
# | Самара | Мебель | 93000 |
# | Москва | Мебель | 76000 |
# | Казань | Мебель | 64000 |
#
# Выведите таблицу через `display()`.

# %%
# Напишите решение ниже

# %% [markdown]
# ## Задача 4. Первичная проверка
#
# В одной ячейке выведите:
#
# - первые строки;
# - размер таблицы;
# - типы данных;
# - описательную статистику числовых полей.

# %%
# Используйте DataFrame sales
# Напишите решение ниже

# %% [markdown]
# ## Задача 5. Отдельные смысловые блоки
#
# Создайте Markdown-заголовок `## Расчёт показателей`.
#
# Под ним в кодовой ячейке рассчитайте общую и среднюю выручку.

# %% [markdown]
# <!-- Добавьте здесь заголовок смыслового блока -->

# %%
# Используйте DataFrame sales
# Напишите решение ниже

# %% [markdown]
# ## Задача 6. Итоговая таблица
#
# Сгруппируйте выручку по городам. Сохраните результат в `city_revenue` и выведите его.

# %%
# Используйте DataFrame sales
# Напишите решение ниже

# %% [markdown]
# ## Задача 7. Визуальный вывод
#
# Постройте столбчатую диаграмму выручки по городам.
#
# Обязательные элементы:
#
# - размер рисунка;
# - заголовок;
# - подписи осей;
# - `tight_layout()`.

# %%
# Используйте DataFrame city_revenue
# Напишите решение ниже

# %% [markdown]
# ## Задача 8. Аналитический вывод
#
# В следующей Markdown-ячейке сформулируйте вывод из 2–3 предложений:
#
# - какой город лидирует;
# - какое ограничение есть у такого вывода.

# %% [markdown]
# <!-- Напишите аналитический вывод -->

# %% [markdown]
# ## Задача 9. Проверка порядка выполнения
#
# Перезапустите среду и выполните **Run all**.
#
# В кодовой ячейке ниже создайте список контрольных статусов:
#
# ```python
# checks = [
#     "Таблица создана",
#     "Показатели рассчитаны",
#     "График построен",
#     "Вывод сформулирован"
# ]
# ```
#
# Выведите каждый пункт с префиксом `OK:`.

# %%
# Напишите решение ниже

# %% [markdown]
# ## Задача 10. Финальная структура notebook
#
# Проверьте, что notebook имеет последовательность:
#
# 1. название и цель;
# 2. импорты;
# 3. данные;
# 4. первичная проверка;
# 5. расчёты;
# 6. итоговая таблица;
# 7. график;
# 8. вывод;
# 9. чек-лист.
#
# В следующей Markdown-ячейке отметьте выполненные пункты символом `[x]`.

# %% [markdown]
# - [ ] Название и цель
# - [ ] Импорты
# - [ ] Данные
# - [ ] Первичная проверка
# - [ ] Расчёты
# - [ ] Итоговая таблица
# - [ ] График
# - [ ] Вывод
# - [ ] Чек-лист

# %% [markdown]
# # Итоговый чек-лист
#
# - [ ] Все разделы выполнены.
# - [ ] Все кодовые ячейки запускаются без ошибок.
# - [ ] Notebook выполняется сверху вниз.
# - [ ] Результаты расчётов выведены.
# - [ ] График построен и подписан.
# - [ ] Аналитический вывод сформулирован.
# - [ ] Файл сохранён в формате `.ipynb`.
